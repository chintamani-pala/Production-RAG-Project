# %%
from langchain_litellm import ChatLiteLLM, LiteLLMEmbeddings

model = ChatLiteLLM(
            model_name="nvidia_nim/nvidia/nemotron-3-nano-omni-30b-a3b-reasoning",
            temperature=0,
            request_timeout=30,
            max_retries=0, # We handle retries outselves
            api_key="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"
        )

model.invoke("Hi")
