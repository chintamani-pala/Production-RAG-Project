# %% [markdown]
# ### Production ready API
# ![Production ready API](./images/prod_ready_api.jpg)
#
#
# ### Production LLM API Request Flow Diagram
# ![Production LLM API Request Flow Diagram](./images/flow_diagram.jpg)
